# %% [markdown]
# <a href="https://colab.research.google.com/github/paruliansaragi/DL-Notebooks/blob/master/Statistical_Foundations_of_Data_Science_todo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv'); df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
np.mean(df['longitude'], )
# Out:
# -119.5621082352941

# %%
??np.mean()

# %%
l2_norm = np.sqrt(np.std(df.longitude))

# %%
l1_norm = np.mean(np.abs(df.longitude)); l1_norm
# Out:
# 119.5621082352941

# %%
np.var(df.longitude)
# Out:
# 4.020455814167474

# %%
from scipy.stats import iqr

iqr(df.longitude)
# Out:
# 3.7900000000000063

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df.longitude)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f44703a7240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f44703a7cf8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f44703ada58>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f44703ad5f8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f44703a73c8>,
#   <matplotlib.lines.Line2D at 0x7f44703a7898>]}

# %%
plt.hist(df.longitude)
# Out:
# (array([ 161., 1251., 3756., 1384.,  881., 2403., 5116., 1866.,  157.,
#           25.]),
#  array([-124.35 , -123.346, -122.342, -121.338, -120.334, -119.33 ,
#         -118.326, -117.322, -116.318, -115.314, -114.31 ]),
#  <a list of 10 Patch objects>)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
np.corrcoef(df.longitude, df.latitude)
# Out:
# array([[ 1.        , -0.92520828],
#        [-0.92520828,  1.        ]])

# %%
plt.scatter(df.longitude, df.latitude)

# %%
np.cov([df.longitude, df.latitude], df.total_rooms)
# Out:
# array([[ 4.02069233e+00, -3.96518544e+00,  2.05489998e+02],
#        [-3.96518544e+00,  4.56822140e+00, -1.80652575e+02],
#        [ 2.05489998e+02, -1.80652575e+02,  4.75216923e+06]])

# %%
np.sum(np.dot(df.longitude, df.latitude))
# Out:
# -72477662.71449997

# %%
from scipy.stats import pearsonr

pearsonr(df.longitude, df.total_rooms)
# Out:
# (0.04701044032857277, 8.658973833917439e-10)

# %%
plt.matshow(df.corr())

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
plot_corr(df)

# %%
plt.scatter(df.longitude, df.median_income)

# %%
plt.contour([df.median_income, df.total_rooms])
